# %%
import pandas as pd

# %% [markdown]
# ### Data Importing

# %%
df = pd.read_csv(r"D:\data\data\datawh.csv")
df
# Out:
#          Dates  Temperature  Humidity  Pressure  Air Quality
# 0   30-04-2018          218       182         4            2
# 1   01-05-2018         2592       182         3            2
# 2   02-05-2018          509       439         4            0
# 3   03-05-2018         2439        53         5            1
# 4   04-05-2018          824       444         5            0
# 5   05-05-2018         1744       443         5            1
# 6   06-05-2018          786       226         5            1
# 7   07-05-2018         1326       309         0            1
# 8   08-05-2018         1804       188         4            2
# 9   09-05-2018          109       420         0            1
# 10  10-05-2018         2524       433         1            0
# 11  11-05-2018         2945       149         1            0
# 12  12-05-2018         2168       531         1            1
# 13  13-05-2018         1318       360         3            2
# ...

# %%
df = pd.read_csv(r"D:\data\data\datanh.csv",header=None)
df
# Out:
#      0   1   2   3
# 0   18  37  22  10
# 1   16  27  19  30
# 2   19  49  19  16
# 3   30  36  21  13
# 4   23  45  16  13
# 5   12  47  22  19
# 6   10  30  21  14
# 7   19  49  24  24
# 8   31  36   9  17
# 9   18  26  17  19
# 10  14  52  11  19
# 11  29  31  17  25
# 12  24  49  24  32
# 13  16  26  18  30
# 14  16  38  10  27
# 15  32  28  24  28
# 16  20  47   6  34
# 17  32  40  23  30
# 18  24  25  10  32
# 19  31  21  11  34

# %%
df.columns = ["temp","humidity","air quality",'pressure']
df
# Out:
#     temp  humidity  air quality  pressure
# 0     18        37           22        10
# 1     16        27           19        30
# 2     19        49           19        16
# 3     30        36           21        13
# 4     23        45           16        13
# 5     12        47           22        19
# 6     10        30           21        14
# 7     19        49           24        24
# 8     31        36            9        17
# 9     18        26           17        19
# 10    14        52           11        19
# 11    29        31           17        25
# 12    24        49           24        32
# 13    16        26           18        30
# 14    16        38           10        27
# 15    32        28           24        28
# 16    20        47            6        34
# 17    32        40           23        30
# 18    24        25           10        32
# 19    31        21           11        34

# %%
df = pd.read_csv(r"D:\data\data\datawh.csv",index_col=['Dates'])
df.shape
# Out:
# (20, 4)

# %%
df.head()
# Out:
#             Temperature  Humidity  Pressure  Air Quality
# Dates
# 30-04-2018          218       182         4            2
# 01-05-2018         2592       182         3            2
# 02-05-2018          509       439         4            0
# 03-05-2018         2439        53         5            1
# 04-05-2018          824       444         5            0

# %%
df["05-05-2018":"12-05-2018"]
# Out:
#             Temperature  Humidity  Pressure  Air Quality
# Dates
# 05-05-2018         1744       443         5            1
# 06-05-2018          786       226         5            1
# 07-05-2018         1326       309         0            1
# 08-05-2018         1804       188         4            2
# 09-05-2018          109       420         0            1
# 10-05-2018         2524       433         1            0
# 11-05-2018         2945       149         1            0
# 12-05-2018         2168       531         1            1

# %%
x = "Hello from \new python"
print(x)
# Out:
# Hello from
# ew python

# %%
x = r"Hello from \new python"
print(x)
# Out:
# Hello from \new python

# %%
# code to load an excel file - data.xlsx

# %%
# loading data from html
# output of read_html will be a list of dataframes
df_list = pd.read_html("https://id.wikipedia.org/wiki/Provinsi_di_Indonesia")
type(df_list)
# Out:
# list

# %%
len (df_list)
# Out:
# 11

# %%
df_list[2]
# Out:
#    Provinsi Baru(Nama sekarang)  Tahun   Provinsi Baru(Nama dulu)  \
# 0                          Aceh   1956   Nanggroe Aceh Darussalam
# 1             Kalimantan Tengah   1958              Borneo Tengah
# 2                       Lampung   1964                    Lampung
# 3               Sulawesi Tengah   1964            Sulawesi Tengah
# 4             Sulawesi Tenggara   1964  Sulawesi Selatan Tenggara
# 5                      Bengkulu   1967                   Bengkulu
# 6                   Papua Barat   1999           Irian Jaya Barat
# 7                  Maluku Utara   1999               Maluku Utara
# 8                        Banten   2000                     Banten
# 9     Kepulauan Bangka Belitung   2000  Kepulauan Bangka Belitung
# 10                    Gorontalo   2000                  Gorontalo
# 11               Kepulauan Riau   2002             Kepulauan Riau
# 12               Sulawesi Barat   2004             Sulawesi Barat
# ...

# %%
df = df_list[4]
df
# Out:
#                   lbsTopik Indonesia  \
# 0   Sejarah Nusantara(pra-Indonesia)
# 1                  Sejarah Indonesia
# 2                           Geografi
# 3           Politik dan pemerintahan
# 4                            Ekonomi
# 5                          Demografi
# 6                             Budaya
# 7                             Simbol
# 8                    Flora dan fauna
# 9                            Lainnya
# 10              Garis besarʥ Portal
#
#                                  lbsTopik Indonesia.1
# 0   Prasejarah Kerajaan Hindu-Buddha Kerajaan Isla...
# 1   Sejarah nama Proklamasi Era transisi Revolusi ...
# 2   Air terjun Bendungan dan waduk Danau Gunung Pe...
# 3   Ibu kota negara Lembaga negara Pemerintah Pres...
# 4   APBN APBD Bank Pasar modal IDX JFX Pariwisata ...
# 5   Suku bangsa Bahasa nasional Bahasa daerah Agam...
# 6   Seni Film Tari Sastra Musik Lagu Masakan Mitol...
# 7   Sang Saka Merah Putih Garuda Pancasila Ibu Per...
# ...

# %% [markdown]
# ## Exporting Data using Pandas

# %%
df.to_excel(r"D:\Bootcamp One Week Intensive at BootUP\Import BootUP\Provinsi_Indonesia_Data.xlsx")
df
# Out:
#                   lbsTopik Indonesia  \
# 0   Sejarah Nusantara(pra-Indonesia)
# 1                  Sejarah Indonesia
# 2                           Geografi
# 3           Politik dan pemerintahan
# 4                            Ekonomi
# 5                          Demografi
# 6                             Budaya
# 7                             Simbol
# 8                    Flora dan fauna
# 9                            Lainnya
# 10              Garis besarʥ Portal
#
#                                  lbsTopik Indonesia.1
# 0   Prasejarah Kerajaan Hindu-Buddha Kerajaan Isla...
# 1   Sejarah nama Proklamasi Era transisi Revolusi ...
# 2   Air terjun Bendungan dan waduk Danau Gunung Pe...
# 3   Ibu kota negara Lembaga negara Pemerintah Pres...
# 4   APBN APBD Bank Pasar modal IDX JFX Pariwisata ...
# 5   Suku bangsa Bahasa nasional Bahasa daerah Agam...
# 6   Seni Film Tari Sastra Musik Lagu Masakan Mitol...
# 7   Sang Saka Merah Putih Garuda Pancasila Ibu Per...
# ...
